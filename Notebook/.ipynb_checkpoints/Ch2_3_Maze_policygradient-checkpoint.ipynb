# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize=(5,5))
ax = plt.gca()

plt.plot([1,1],[0,1],color='red',linewidth=2)
plt.plot([1,2],[2,2],color='red',linewidth=2)
plt.plot([2,2],[2,1],color='red',linewidth=2)
plt.plot([2,3],[1,1],color='red',linewidth=2)

fig = plt.figure(figsize=(5,5))
ax = plt.gca()

plt.plot([1,1],[0,1],color='red',linewidth=2)
plt.plot([1,2],[2,2],color='red',linewidth=2)
plt.plot([2,2],[2,1],color='red',linewidth=2)
plt.plot([2,3],[1,1],color='red',linewidth=2)

plt.text(0.5,2.5,'S0',size=14,ha='center')
plt.text(1.5,2.5,'S1',size=14,ha='center')
plt.text(2.5,2.5,'S2',size=14,ha='center')
plt.text(0.5,1.5,'S3',size=14,ha='center')
plt.text(1.5,1.5,'S4',size=14,ha='center')
plt.text(2.5,1.5,'S5',size=14,ha='center')
plt.text(0.5,0.5,'S6',size=14,ha='center')
plt.text(1.5,0.5,'S7',size=14,ha='center')
plt.text(2.5,0.5,'S8',size=14,ha='center')
plt.text(0.5,2.3,'START',ha='center')
plt.text(2.5,0.3,'GOAL',ha='center')

ax.set_xlim(0,3)
ax.set_ylim(0,3)
plt.tick_params(axis='both', which='both', bottom=False, top=False,
                labelbottom=False, right=False, left=False, labelleft=False)

line, = ax.plot([0.5],[2.5],marker="o",color='g',markersize = 60)

# %%
theta_0 = np.array([[np.nan, 1, 1, np.nan],
                  [np.nan, 1, np.nan, 1],
                  [np.nan, np.nan, 1, 1],
                  [1, 1, 1, np.nan],
                  [np.nan, np.nan, 1, 1],
                  [1, np.nan, np.nan, np.nan],
                  [1, np.nan, np.nan, np.nan],
                  [1, 1, np.nan, np.nan]
                   ])

# %%
def simple_convert_into_pi_from_theta(theta):
    [m, n] = theta.shape
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])
        
    pi = np.nan_to_num(pi)
    
    return pi

def softmax_convert_into_pi_from_theta(theta):
    beta = 1.0
    [m, n] = theta.shape
    pi = np.zeros((m,n))
    
    exp_theta = np.exp(beta * theta)
    
    for i in range(0, m):
        pi[i, :] = exp_theta[i, :] / np.nansum(exp_theta[i, :])
        
    pi = np.nan_to_num(pi)
    
    return pi

# %%
#pi_0 = simple_convert_into_pi_from_theta(theta_0)
pi_0 = softmax_convert_into_pi_from_theta(theta_0)

print(pi_0)
# Out:
# [[0.         0.5        0.5        0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.33333333 0.33333333 0.33333333 0.        ]
#  [0.         0.         0.5        0.5       ]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.5        0.5        0.         0.        ]]

# %%
def get_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    
    next_direction = np.random.choice(direction, p=pi[s, :])
    
    if next_direction == "up":
        s_next = s - 3
    elif next_direction == "right":
        s_next = s + 1
    elif next_direction == "down":
        s_next = s + 3
    elif next_direction == "left":
        s_next = s - 1
        
    return s_next

def get_action_and_next_s(pi, s):
    direction = ["up", "right", "down", "left"]
    
    next_direction = np.random.choice(direction, p=pi[s, :])
    
    if next_direction == "up":
        action = 0
        s_next = s - 3
    elif next_direction == "right":
        action = 1
        s_next = s + 1
    elif next_direction == "down":
        action = 2
        s_next = s + 3
    elif next_direction == "left":
        action = 3
        s_next = s - 1    
    
    return [action, s_next]

# %%
def goal_maze(pi):
    s = 0
    state_history = [0]
    
    while(1):
        next_s = get_next_s(pi, s)
        state_history.append(next_s)
        
        if next_s == 8:
            break
        else:
            s = next_s
            
    return state_history

def goal_maze_ret_s_a(pi):
    s = 0
    s_a_history = [[0, np.nan]]
    
    while (1):
        [action, next_s] = get_action_and_next_s(pi, s)
        s_a_history[-1][1] = action
        
        s_a_history.append([next_s, np.nan])
        
        if next_s == 8:
            break
        else:
            s = next_s
            
    return s_a_history

# %%
state_history = goal_maze(pi_0)

print(state_history)
print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(state_history) -1 ) +"단계입니다.")

# %%
s_a_history = goal_maze_ret_s_a(pi_0)

print(s_a_history)
print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) -1 ) +"단계입니다.")
# Out:
# [[0, 2], [3, 2], [6, 0], [3, 1], [4, 2], [7, 1], [8, nan]]
# 목표 지점에 이르기까지 걸린 단계 수는 6단계입니다.

# %%
# theta를 수정하는 함수

def update_theta(theta, pi, s_a_history):
    eta = 0.1 #학습률
    T = len(s_a_history) - 1 # 목표 지점에 이르기까지 걸린 단계 수
    
    [m, n] = theta.shape # theta의 행렬 크기를 구함
    delta_theta = theta.copy() # 델타 theta를 구할 준비, 포인터 참조이므로 delta_theta = theta로는 안 됨
    # 만약 delta_theta = theta로 하고 계산한다면 delta_theta를 수정할 때 theta도 같이 수정이 되어버린다.
    
    # delta_theta를 요소 단위로 계산
    for i in range(0, m):
        for j in range(0, n):
            if not(np.isnan(theta[i, j])): # theta 가 nan이 아닌 경우
                SA_i = [SA for SA in s_a_history if SA[0] == i]
                # 히스토리에서 상태 i인 것만 모아오는 리스트 컴프리헨션
                
                SA_ij = [SA for SA in s_a_history if SA ==[i,j]]
                # 상태 i에서 행동 j를 취한 경우만 모음
                
                N_i = len(SA_i) # 상태 i에서 모든 행동을 취한 횟수
                N_ij = len(SA_ij) # 상태 i에서 행동 j를 취한 횟수
                
                delta_theta[i, j] = (N_ij - pi[i, j] * N_i) / T
    new_theta = theta + eta * delta_theta
    
    return new_theta

# %%
# 정책 수정
new_theta = update_theta(theta_0, pi_0, s_a_history)
pi = softmax_convert_into_pi_from_theta(new_theta)
print(pi)
# Out:
# [[0.         0.49583343 0.50416657 0.        ]
#  [0.         0.5        0.         0.5       ]
#  [0.         0.         0.5        0.5       ]
#  [0.32963997 0.33518001 0.33518001 0.        ]
#  [0.         0.         0.50416657 0.49583343]
#  [1.         0.         0.         0.        ]
#  [1.         0.         0.         0.        ]
#  [0.49583343 0.50416657 0.         0.        ]]

# %%
# 정책 경사 알고리즘으로 미로 빠져나오기

# 초기 세팅
stop_epsilon = 10**-4 # 정책의 변화가 10^-4보다 작아지면 학습을 종료

theta = theta_0
pi = pi_0

is_continue = True
count = 1

while is_continue: # is_continue가 False가 될 때까지 반복
    s_a_history = goal_maze_ret_s_a(pi) # 정책 pi를 따라 미로를 탐색한 히스토리를 구함
    new_theta = update_theta(theta, pi, s_a_history) # 파라미터 theta를 수정
    new_pi = softmax_convert_into_pi_from_theta(new_theta) # 정책 pi를 수정
    
    print(np.sum(np.abs(new_pi - pi))) # 정책의 변화를 출력
    print("목표 지점에 이르기까지 걸린 단계수는 " + str(len(s_a_history) - 1) + "단계입니다.")
    
    if np.sum(np.abs(new_pi - pi)) < stop_epsilon:
        is_continue = False
    else:
        theta= new_theta
        pi = new_pi
# Out:
# 0.03242728974704956
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.009299037417839828
# 목표 지점에 이르기까지 걸린 단계수는 50단계입니다.
# 0.009488713745126165
# 목표 지점에 이르기까지 걸린 단계수는 50단계입니다.
# 0.013588408727869816
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.0086671635529742
# 목표 지점에 이르기까지 걸린 단계수는 68단계입니다.
# 0.009325225686903305
# 목표 지점에 이르기까지 걸린 단계수는 74단계입니다.
# 0.026041350852728462
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.017702611109563726
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.012383775302860112
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.006685434399056833
# 목표 지점에 이르기까지 걸린 단계수는 90단계입니다.
# 0.03650208821456591
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.00831310161585308
# 목표 지점에 이르기까지 걸린 단계수는 44단계입니다.
# 0.012260076142530552
# 목표 지점에 이르기까지 걸린 단계수는 22단계입니다.
# 0.01643721357327138
# 목표 지점에 이르기까지 걸린 단계수는 46단계입니다.
# 0.01026360648469149
# 목표 지점에 이르기까지 걸린 단계수는 74단계입니다.
# 0.01340166051218361
# 목표 지점에 이르기까지 걸린 단계수는 80단계입니다.
# 0.014254625971774793
# 목표 지점에 이르기까지 걸린 단계수는 48단계입니다.
# 0.005796160946752615
# 목표 지점에 이르기까지 걸린 단계수는 94단계입니다.
# 0.016506133354684704
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.01273407166936813
# 목표 지점에 이르기까지 걸린 단계수는 34단계입니다.
# 0.006404805180904305
# 목표 지점에 이르기까지 걸린 단계수는 156단계입니다.
# 0.01120426456762108
# 목표 지점에 이르기까지 걸린 단계수는 42단계입니다.
# 0.011051214219585492
# 목표 지점에 이르기까지 걸린 단계수는 42단계입니다.
# 0.007987710432523276
# 목표 지점에 이르기까지 걸린 단계수는 32단계입니다.
# 0.005760228966102565
# 목표 지점에 이르기까지 걸린 단계수는 232단계입니다.
# 0.032374043053690515
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.009439028240429581
# 목표 지점에 이르기까지 걸린 단계수는 78단계입니다.
# 0.02346962992295165
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.009409551983340592
# 목표 지점에 이르기까지 걸린 단계수는 26단계입니다.
# 0.012393363177305938
# 목표 지점에 이르기까지 걸린 단계수는 62단계입니다.
# 0.009228889308056654
# 목표 지점에 이르기까지 걸린 단계수는 86단계입니다.
# 0.005745110079255267
# 목표 지점에 이르기까지 걸린 단계수는 140단계입니다.
# 0.025678033690522184
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.014490449703086494
# 목표 지점에 이르기까지 걸린 단계수는 58단계입니다.
# 0.012986879918122252
# 목표 지점에 이르기까지 걸린 단계수는 52단계입니다.
# 0.01269688593078322
# 목표 지점에 이르기까지 걸린 단계수는 26단계입니다.
# 0.010671032874357667
# 목표 지점에 이르기까지 걸린 단계수는 50단계입니다.
# 0.006563683486229932
# 목표 지점에 이르기까지 걸린 단계수는 70단계입니다.
# 0.02279618635235836
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.018219836459470118
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.02151492030256158
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.024653213561218856
# 목표 지점에 이르기까지 걸린 단계수는 22단계입니다.
# 0.0237195846640611
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.027649693524665453
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.023670479721572713
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.012839053221751273
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.007489621523970702
# 목표 지점에 이르기까지 걸린 단계수는 64단계입니다.
# 0.04708528544981527
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.018291249400487486
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.016824619330251367
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.007721529160730045
# 목표 지점에 이르기까지 걸린 단계수는 60단계입니다.
# 0.00878014047852671
# 목표 지점에 이르기까지 걸린 단계수는 78단계입니다.
# 0.009737526102581218
# 목표 지점에 이르기까지 걸린 단계수는 42단계입니다.
# 0.009619059871986857
# 목표 지점에 이르기까지 걸린 단계수는 64단계입니다.
# 0.02386198612499335
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.021030530612685394
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.012579202404782164
# 목표 지점에 이르기까지 걸린 단계수는 40단계입니다.
# 0.007398852855220239
# 목표 지점에 이르기까지 걸린 단계수는 44단계입니다.
# 0.00678997789364888
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.028304479698391616
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.01708141427252896
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.035980237227481116
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.007211155341947106
# 목표 지점에 이르기까지 걸린 단계수는 74단계입니다.
# 0.03127007933608772
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.012405945383910488
# 목표 지점에 이르기까지 걸린 단계수는 40단계입니다.
# 0.02972431293047073
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.007809083350938106
# 목표 지점에 이르기까지 걸린 단계수는 64단계입니다.
# 0.017777974906128258
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.02204411618844926
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.015474008797167371
# 목표 지점에 이르기까지 걸린 단계수는 48단계입니다.
# 0.011313850627074962
# 목표 지점에 이르기까지 걸린 단계수는 92단계입니다.
# 0.015252049653158517
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.011560059184179516
# 목표 지점에 이르기까지 걸린 단계수는 48단계입니다.
# 0.016950105179986963
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.011283569065694832
# 목표 지점에 이르기까지 걸린 단계수는 68단계입니다.
# 0.016653505367155652
# 목표 지점에 이르기까지 걸린 단계수는 24단계입니다.
# 0.020534453489736204
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.009654595336621441
# 목표 지점에 이르기까지 걸린 단계수는 24단계입니다.
# 0.02335975779567634
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.04508750109276721
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.023628529410366417
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.03516137736997271
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.018193577154025975
# 목표 지점에 이르기까지 걸린 단계수는 26단계입니다.
# 0.01997987776690746
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.012115199090880435
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.009086529857314618
# 목표 지점에 이르기까지 걸린 단계수는 64단계입니다.
# 0.012670901510643373
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.018302209989830842
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.012208094554203075
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.014104973360591244
# 목표 지점에 이르기까지 걸린 단계수는 32단계입니다.
# 0.012007409090824817
# 목표 지점에 이르기까지 걸린 단계수는 62단계입니다.
# 0.008509326401620165
# 목표 지점에 이르기까지 걸린 단계수는 108단계입니다.
# 0.019681884715412823
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.007618416630331082
# 목표 지점에 이르기까지 걸린 단계수는 46단계입니다.
# 0.010400168217984007
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.02748400941794421
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.044364622227600625
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.022373308246187107
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.011053552652487975
# 목표 지점에 이르기까지 걸린 단계수는 32단계입니다.
# 0.030455391750819738
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.031964546814763184
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.04329035181863261
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.013268307569932525
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.008102720192777246
# 목표 지점에 이르기까지 걸린 단계수는 78단계입니다.
# 0.016278145670080513
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.026740039863794474
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.03713603928721687
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.01814160239739243
# 목표 지점에 이르기까지 걸린 단계수는 34단계입니다.
# 0.017001914626575798
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.013707131935972783
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.037550762977085095
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.00798589838446373
# 목표 지점에 이르기까지 걸린 단계수는 46단계입니다.
# 0.02068631165054191
# 목표 지점에 이르기까지 걸린 단계수는 46단계입니다.
# 0.01714260884085167
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.03442048305771078
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.011981014201569329
# 목표 지점에 이르기까지 걸린 단계수는 34단계입니다.
# 0.011014789580465145
# 목표 지점에 이르기까지 걸린 단계수는 44단계입니다.
# 0.042315994103552024
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.036082032586219115
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.019174224114590854
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.019026130975707545
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.009141751134810971
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.02097981136447724
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.010729136425101482
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.009265824597934569
# 목표 지점에 이르기까지 걸린 단계수는 100단계입니다.
# 0.011546529174873754
# 목표 지점에 이르기까지 걸린 단계수는 42단계입니다.
# 0.018903326338725546
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.041607550507981206
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.01516233988364224
# 목표 지점에 이르기까지 걸린 단계수는 36단계입니다.
# 0.018030430304954825
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.013308991610922194
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.026516203793574777
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.019553673085445866
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.040414455573221875
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.015490827955051356
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.016752855493371188
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.012541533138420824
# 목표 지점에 이르기까지 걸린 단계수는 40단계입니다.
# 0.011650609114250032
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.0373222710850003
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.011329485587873
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.016283593230425608
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.013223012658496958
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.019551826153818674
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.03992463709167443
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.021461297257791834
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.01720875675855177
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.02385909709723455
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.028802672076327196
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.013753075695101313
# 목표 지점에 이르기까지 걸린 단계수는 40단계입니다.
# 0.017357485508847748
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.017374432461773004
# 목표 지점에 이르기까지 걸린 단계수는 20단계입니다.
# 0.03917502148683388
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.02815355245161527
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.019824832377347668
# 목표 지점에 이르기까지 걸린 단계수는 24단계입니다.
# 0.027840752397783608
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.028141003614360782
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.011228008793539218
# 목표 지점에 이르기까지 걸린 단계수는 34단계입니다.
# 0.023062112626396708
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.031756516790170025
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.007442444176529145
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.011096986548735865
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.029772729047924745
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.030547787052422892
# 목표 지점에 이르기까지 걸린 단계수는 12단계입니다.
# 0.015471498928085414
# 목표 지점에 이르기까지 걸린 단계수는 24단계입니다.
# 0.021808470383101214
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.022170124403710356
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.02975404950447677
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.02457807453255398
# 목표 지점에 이르기까지 걸린 단계수는 10단계입니다.
# 0.014190722768514352
# 목표 지점에 이르기까지 걸린 단계수는 24단계입니다.
# 0.012683102443369038
# 목표 지점에 이르기까지 걸린 단계수는 18단계입니다.
# 0.02238308070162548
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.018257758706306165
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.021839925251993547
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.022598709952275947
# 목표 지점에 이르기까지 걸린 단계수는 8단계입니다.
# 0.010671031161529093
# 목표 지점에 이르기까지 걸린 단계수는 28단계입니다.
# 0.011873645564688201
# 목표 지점에 이르기까지 걸린 단계수는 54단계입니다.
# 0.023089161632167676
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.015117865522664586
# 목표 지점에 이르기까지 걸린 단계수는 30단계입니다.
# 0.012098256847081768
# 목표 지점에 이르기까지 걸린 단계수는 26단계입니다.
# 0.01125026737606577
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.012867620740949659
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.014655119198080768
# 목표 지점에 이르기까지 걸린 단계수는 14단계입니다.
# 0.016874688394420023
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.016313422919346177
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0.02524549013741817
# 목표 지점에 이르기까지 걸린 단계수는 16단계입니다.
# 0
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010653732529243738
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010637011793590903
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010620330599940032
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010603688822971927
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010587086337964825
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010570523020650077
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010553998747270255
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010537513394512192
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010521066839628418
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010504658960295947
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010488289634655139
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010471958741447435
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010455666159760353
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.0001043941176925127
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010423195449916871
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010407017082437672
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010390876547795164
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010374773727485354
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010358708503553464
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010342680758262772
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.0011560126723712486
# 목표 지점에 이르기까지 걸린 단계수는 6단계입니다.
# 0.00010513817622719024
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010497380181384054
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010480981526113722
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010464621534313732
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010448300083545914
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010432017052062342
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010415772318657888
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010399565762324835
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010383397262766006
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010367266700142715
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010351173955014045
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010335118908473724
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010319101442056618
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010303121437729539
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010287178778014411
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010271273345785828
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010255405024542363
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010239573698047309
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010223779250623406
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010208021567080158
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010192300532618076
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010176616032872912
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.000101609679540135
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.0001014535618260367
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010129780605569287
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010114241110470261
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010098737585171984
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.0001008326991790761
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.0001006783799756758
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010052441713253105
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010037080954687985
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010021755611844783
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 0.00010006465575198437
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.
# 9.991210735763034e-05
# 목표 지점에 이르기까지 걸린 단계수는 4단계입니다.

# %%
# 학습이 끝난 정책을 확인
np.set_printoptions(precision=3, suppress=True) 
#유효 자릿수 3, suppress = True : 정해진 자리수만큼 point notation으로 표시해줌, 지수는 표시하지 않도록 설정
print(pi)
# Out:
# [[0.    0.014 0.986 0.   ]
#  [0.    0.275 0.    0.725]
#  [0.    0.    0.419 0.581]
#  [0.012 0.976 0.012 0.   ]
#  [0.    0.    0.987 0.013]
#  [1.    0.    0.    0.   ]
#  [1.    0.    0.    0.   ]
#  [0.016 0.984 0.    0.   ]]

# %%
# 에이전트의 이동 과정을 시각화
from matplotlib import animation
from IPython.display import HTML

def init():
    line.set_data([],[])
    return (line,)

def animate(i):
    state = state_history[i]
    x = (state % 3) + 0.5
    y = 2.5 - int(state / 3)
    line.set_data(x, y)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func = init, frames = len(state_history), interval = 200, repeat = False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img3825b16abb344d8f8c3877c51739c5a1">
#     <br>
#     <input id="_anim_slider3825b16abb344d8f8c3877c51739c5a1" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim3825b16abb344d8f8c3877c51739c5a1.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim3825b16abb344d8f8c3877c51739c5a1.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select3825b16abb344d8f8c3877c51739c5a1" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img3825b16abb344d8f8c3877c51739c5a1";
#     var slider_id = "_anim_slider3825b16abb344d8f8c3877c51739c5a1";
#     var loop_select_id = "_anim_loop_select3825b16abb344d8f8c3877c51739c5a1";
#     var frames = new Array(69);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAHJpJREFUeJzt3XtwVPX9//HXJruBJJsUfoCYiyYo\
# lRh+IpLAEGilEpRYh1pFcBIvQCxqpdavxME6pXjpz46NRgYrP0fmC1G8KygGp1pSwDCAFcJF/HJR\
# +dYIBCyQgpB7lv18/1jCl0sgCSQ5n919PmYyDtlL3vsxeebk5OQclzHGCABgnQinBwAAtIxAA4Cl\
# CDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQA\
# WIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpA\
# A4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4ClCDQAWIpAA4Cl\
# CDQAWIpAA4Cl3E4PcD569+6t1NRUp8cAEGIqKip08OBBp8c4ISgDnZqaqvLycqfHABBiMjMznR7h\
# FOziAABLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSBBgBLEWgAsBSB\
# BgBLEWgAsFRQnm7UZsYYVR6t1Ia9G7Sucp3KvivTtgPbVOerk8/v0zH/MUVGRMod4Va0O1rpfdI1\
# KmWUhiUNU0ZihpLikuRyuZx+GQAsQKA7gN/4tfyfy/X8P57Xml1r5PP75In0qLqxWn7jP+P+Pr9P\
# Pr9P9b56rdm9Rp/t+UzeKK8ajzXKE+HRyEtHavrw6cq+LFsRLn7IAcIVgb4Ah+oOacGmBSr6rEhH\
# G4+qurH6xG11vro2P4/f+HWk4YgkqV71+mTnJ1q9a7XiouJUkFWg/Gvy1TO6Z4fPD8BubJ6dhz1H\
# 9ihvcZ4Sn0/UrE9naV/1vlPi3BGqG6u1r3qfZn06S4nPJ+qOxXdoz5E9HfoxANiNQLeDMUbzN81X\
# 2otpem/re6r31au2qbZTP2ZtU63qffV6d+u7SnsxTfM3zZcxplM/JgA7EOg2qjxSqetevU4PffyQ\
# appq5DO+Lv34PuNTTVONHvr4IV336nWqPFLZpR8fQNcj0G1QvLlYaS+mac3uNappqnF0lpqmGq3Z\
# vUZpc9NUvLnY0VkAdC4CfQ7GGD38ycP6zV9/o+qmavn8XbvVfDY+v0/VjdX6zV9/o+l/m84uDyBE\
# EeizOOY/pslLJmvexnmdvp/5fNU21erlDS9ryodTdMx/zOlxAHQwDrNrgTFG+R/ma9H2RdbGuVlt\
# U63e2/aeJKn45mL+yAUIIWxBt2D636Zr8fbF1se5WXOkC5YVOD0KgA5EoE9TvLlY8zbOc/yXge3V\
# vLuDXxwCoYNAn6TySKV++9ffBs2W8+lqm2r1249/yyF4QIgg0McZY5T3fp7qj9U7PcoFafA16I73\
# 7+DIDiAEEOjjFmxeoA17N1hzKN35avI3qXxvObs6gBBAoBU4t0bzXwiGgpqmGj30yUPs6gCCHIGW\
# NKN0hhp8DU6P0aHqffWaUTrD6TEAXICwD/ShukP6YMcHXX5ujc7m8/v0/o73dajukNOjADhPYR/o\
# BZsWhOxJ8SNcEeyLBoJYaJapjfzGr6LPijr+sLoaSR9Jmi3pj5KelfSqpP8+fruRtFLSc5L+n6Ri\
# Sfs7dgQpcNhd0dqiFq/qEkoOHDigBx54QKmpqerWrZv69u2r7OxslZaWSpLef/99jR07Vn369JHL\
# 5dKnn37q7MAh4lzr3tTUpEcffVSDBg1SbGysEhISlJeXp127djk9dlAJ6z/1Xv7P5TraeLTjn/gd\
# SU2Sbpb0fxQIdoWk5u8DayR9JumXknpJKpO0UNKDkrp17ChHGo9oxbcrNOayMR37

# %%
# 에이전트의 이동 과정을 시각화
from matplotlib import animation
from IPython.display import HTML

def init():
    line.set_data([],[])
    return (line,)

def animate(i):
    # 프레임 단위로 이미지 생성
    state = s_a_history[i][0] # 현재 위치
    x = ( state % 3 ) + 0.5 # 상태의 x좌표 : 3으로 나눈 나머지 + 0.5
    y = 2.5 - int(state / 3)
    line.set_data(x,y)
    return (line,)

# 초기화 함수와 프레임 단위 이미지 생성 함수를 사용해 애니메이션 생성
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(s_a_history), interval = 200, repeat = False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgce434457b7184e78b1467fd3ba48f8d3">
#     <br>
#     <input id="_anim_sliderce434457b7184e78b1467fd3ba48f8d3" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animce434457b7184e78b1467fd3ba48f8d3.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animce434457b7184e78b1467fd3ba48f8d3.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectce434457b7184e78b1467fd3ba48f8d3" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgce434457b7184e78b1467fd3ba48f8d3";
#     var slider_id = "_anim_sliderce434457b7184e78b1467fd3ba48f8d3";
#     var loop_select_id = "_anim_loop_selectce434457b7184e78b1467fd3ba48f8d3";
#     var frames = new Array(5);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAA