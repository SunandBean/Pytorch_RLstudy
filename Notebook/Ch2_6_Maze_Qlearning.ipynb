# %%
# 구현에 사용할 패키지 임포트하기
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 초기 상태의 미로 모습

# 전체 그림의 크기 및 그림을 나타내는 변수 선언
fig = plt.figure(figsize = (5,5))
ax = plt.gca()

# 붉은 벽 그리기
plt.plot([1,1],[0,1], color='red',linewidth=2)
plt.plot([1,2],[2,2], color='red',linewidth=2)
plt.plot([2,2],[2,1], color='red',linewidth=2)
plt.plot([2,3],[1,1], color='red',linewidth=2)

# 상태를 의미하는 문자열(S0 ~ S8) 표시
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 그림을 그릴 범위 및 눈금 제거 설정
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis = 'both', which = 'both', bottom=False, top=False, 
                labelbottom=False, right=False, left=False, labelleft=False)

# S0에 녹색 원으로 현재 위치를 표시
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize = 60)

# %%
# 정책을 결정하는 파라미터의 초깃값 theta_0을 설정
 
# 줄은 상태 0~7, 열은 행동 방향(상,우,하,좌 순)을 나타낸다.
theta_0 = np.array([[np.nan, 1, 1, np.nan],
                   [np.nan, 1, np.nan, 1],
                   [np.nan, np.nan, 1, 1],
                   [1, 1, 1, np.nan],
                   [np.nan, np.nan, 1, 1],
                   [1, np.nan, np.nan, np.nan],
                   [1, np.nan, np.nan, np.nan],
                   [1, 1, np.nan, np.nan],
                   ])

# %%
# 행동가치 함수  Q의 초기상태

[a, b] = theta_0.shape # 열과 행의 개수를 변수 a,b에 저장
Q = np.random.rand(a, b) * theta_0
# * theta_0으로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# 정책 파라미터 theta_0 을 무작위 행동 정책 pi로 변환하는 함수

def simple_convert_into_pi_from_theta(theta):
    '''단순 비율 계산'''
    
    [m, n] = theta.shape # theta의 행렬 크기를 구함
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :]) # 비율 계산
    
    pi = np.nan_to_num(pi) # nan을 0으로 변환
    
    return pi

# 무작위 행동정책 pi_0을 계산
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# %%
# e-greedy 알고리즘 구현

def get_action(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    
    # 행동을 결정
    if np.random.rand() < epsilon:
        # 확률 e로 무작위 행동을 선택함
        next_direction = np.random.choice(direction, p=pi_0[s, :]) # 상태 s에서 행동을 선택할 확률인 pi를 이용하여 방향을 랜덤 선택
    else:
        # Q 값이 최대가 되는 행동을 선택함
        next_direction = direction[np.nanargmax(Q[s, :])] # nanargmax - 행렬에서 nan 부분을 제외하고 최대값의 인덱스를 반환
    
    # 행동을 인덱스로 변환
    if next_direction == "up":
        action = 0
    elif next_direction == "right":
        action = 1
    elif next_direction == "down":
        action = 2
    elif next_direction == "left":
        action = 3
    
    return action

def get_s_next(s, a, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
    next_direction = direction[a] # 행동 a의 방향
    
    # 행동으로 다음 상태를 결정
    if next_direction == "up":
        s_next = s - 3 # 위로 이동하면 상태값이 3만큼 줄어든다
    elif next_direction == "right":
        s_next = s + 1 # 오른쪽으로 이동하면 상태값이 1만큼 늘어난다
    elif next_direction == "down":
        s_next = s + 3 # 아래로 이동하면 상태값이 3만큼 늘어난다
    elif next_direction == "left":
        s_next = s - 1 # 왼쪽으로 이동하면 상태값이 1만큼 줄어든다
        
    return s_next

# %%
# Q러닝 알고리즘으로 행동가치 함수 Q를 수정

def Q_learning(s, a, r, s_next, Q, eta, gamma):
    
    if s_next == 8: # 목표 지점에 도달한 경우
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])
        
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next, :]) - Q[s, a])
        # Sarsa 알고리즘과 다른 점: 수정식에 들어가는 다음 상태의 행동가치 함수를 구할 때 
        #                           다음 상태에서의 행동에 대한 고려를 하지 않음(Off-policy)
        
    return Q

# %%
# Q러닝 알고리즘으로 미로를 빠져나오는 함수, 상태 및 행동 그리고 Q값의 히스토리를 출력한다.

def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi):
    s = 0 # 시작지점
    a = a_next = get_action(s, Q, epsilon, pi) # 첫 번째 행동
    s_a_history = [[0, np.nan]] # 에이전트의 행동 및 상태의 히스토리를 기록하는 리스트
    
    while (1): # 목표 지점에 이를 때까지 반복
        a = a_next # 행동 결정
        
        s_a_history[-1][1] = a
        # 현재 상태(마지막이므로 인덱스가 -1)를 히스토리에 추가
        
        s_next = get_s_next(s, a, Q, epsilon, pi)
        # 다음 단계의 상태를 구함
        
        s_a_history.append([s_next, np.nan])
        # 다음 상태를 히스토리에 추가, 행동은 아직 알 수 없으므로 nan으로 둔다
        
        # 보상을 부여하고 다음 행동을 계산
        if s_next == 8:
            r = 1 # 목표 지점에 도달했다면 보상을 부여
            a_next = np.nan
        else:
            r = 0
            a_next = get_action(s_next, Q, epsilon, pi)
            # 다음 행동 a_next 를 계산
            
        # 가치함수르 수정
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)
        
        if s_next == 8:
            break
        else:
            s = s_next
            
    return [s_a_history, Q]

# %%
# 행동가치 함수 Q의 초기상태

[a, b] = theta_0.shape # # 열과 행의 개수를 a, b 변수에 저장
Q = np.random.rand(a, b) * theta_0 * 0.1
# * theta_0으로 요소 단위 곱셈을 수행, Q에서 벽 방향으로 이동하는 행동에는 nan을 부여

# %%
# Q러닝 알고리즘으로 미로 빠져나오기

eta = 0.1 # 학습률
gamma = 0.9 # 시간 할인율
epsilon = 0.5 # e-greedy 알고리즘 epsilon 초깃값
v = np.nanmax(Q, axis = 1) # 각 상태마다 가치의 최댓값을 계산
is_continue = True
episode = 1

V = [] # 에피소드별로 상태가치를 저장
V.append(np.nanmax(Q, axis = 1)) # 상태별로 행동가치의 최댓값을 계산

while is_continue: # is_continue의 값이 False가 될 때까지 반복
    print("에피소드: " + str(episode))
    
    # e 값을 조금씩 감소시킴
    epsilon = epsilon / 2
    
    # Q러닝으로 미로를 빠져나온 후, 결과로 나온 행동 히스토리와 Q 값을 변수에 저장
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)
    
    # 상태가치의 변화
    new_v = np.nanmax(Q, axis = 1) # 각 상태마다 행동가치의 최댓값을 계산
    print(np.sum(np.abs(new_v - v))) # 상태가치 함수의 변화를 출력
    v = new_v
    V.append(v) # 현재 에피소드가 끝난 시점의 상태가치 함수를 추가
    
    print("목표 지점에 이르기까지 걸린 단계 수는 " + str(len(s_a_history) - 1) + "단계입니다.")
    
    # 100 에피소드 반복
    episode = episode + 1
    if episode > 100:
        break
# Out:
# 에피소드: 1
# 0.18680708799925422
# 목표 지점에 이르기까지 걸린 단계 수는 64단계입니다.
# 에피소드: 2
# 0.09663078392514388
# 목표 지점에 이르기까지 걸린 단계 수는 10단계입니다.
# 에피소드: 3
# 0.09255580152148996
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 4
# 0.08993901809851118
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 5
# 0.08898275029848524
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 6
# 0.08803919682509104
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 7
# 0.08709531403329311
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 8
# 0.08613734404586239
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 9
# 0.08515192783442949
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 10
# 0.08412686682519521
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 11
# 0.08305161099586678
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 12
# 0.08191753695137763
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 13
# 0.08071806739514709
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 14
# 0.07944867337877116
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 15
# 0.07810679239899004
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 16
# 0.07669168854598683
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 17
# 0.07520427526100125
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 18
# 0.07364691663775193
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 19
# 0.0720232194345611
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 20
# 0.07033782491100321
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 21
# 0.06859620714458634
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 22
# 0.06680448251818624
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 23
# 0.064969233512251
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 24
# 0.06309734871522257
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 25
# 0.061195880020729704
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 26
# 0.059271917260187185
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 27
# 0.0573324799821284
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 28
# 0.05538442569954302
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 29
# 0.05343437365431575
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 30
# 0.05148864296923539
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 31
# 0.04955320395286583
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 32
# 0.04763364127434727
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 33
# 0.0457351277204166
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 34
# 0.04386240727461299
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 35
# 0.042019786309903606
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 36
# 0.04021113175366947
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 37
# 0.038439875162484816
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 38
# 0.03670902172891638
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 39
# 0.03502116333019628
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 40
# 0.03337849481639549
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 41
# 0.03178283282168354
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 42
# 0.030235636464889692
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 43
# 0.028738029383887587
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 44
# 0.02729082262162391
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 45
# 0.025894537949464336
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 46
# 0.02454943127578113
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 47
# 0.0232555158443023
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 48
# 0.02201258497778258
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 49
# 0.02082023416824197
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 50
# 0.019677882355593757
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 51
# 0.01858479227224863
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 52
# 0.01754008976257948
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 53
# 0.016542782013286184
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 54
# 0.015591774654065693
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 55
# 0.014685887707925005
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 56
# 0.013823870387284942
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 57
# 0.013004414746048742
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 58
# 0.01222616820934741
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 59
# 0.011487745012007444
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 60
# 0.010787736584178198
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 61
# 0.010124720928260333
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 62
# 0.009497271035491917
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 63
# 0.008903962393511211
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 64
# 0.008343379638077186
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 65
# 0.007814122403076773
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 66
# 0.007314810423113216
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 67
# 0.006844087942505017
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 68
# 0.006400627483517329
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 69
# 0.0059831330252272386
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 70
# 0.0055903426426641145
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 71
# 0.00522103065384516
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 72
# 0.0048740093201222745
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 73
# 0.004548130142909668
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 74
# 0.0042422847974403766
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 75
# 0.0039554057417339195
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 76
# 0.0036864665364740867
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 77
# 0.0034344819090528222
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 78
# 0.0031985075926213025
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 79
# 0.0029776399686475274
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 80
# 0.0027710155392083324
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 81
# 0.0025778102530771285
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 82
# 0.002397238707583238
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 83
# 0.0022285532462457125
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 84
# 0.0020710429703290067
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 85
# 0.0019240326806989616
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 86
# 0.0017868817647241908
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 87
# 0.001658983041428086
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 88
# 0.0015397615766665762
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 89
# 0.0014286734787880562
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 90
# 0.0013252046840068754
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 91
# 0.0012288697395932413
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 92
# 0.001139210591956985
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 93
# 0.0010557953857537328
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 94
# 0.0009782172792790478
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 95
# 0.0009060932806412847
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 96
# 0.0008390631084865818
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 97
# 0.0007767880804210314
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 98
# 0.0007189500316845399
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 99
# 0.000665250266137063
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.
# 에피소드: 100
# 0.0006154085411361754
# 목표 지점에 이르기까지 걸린 단계 수는 4단계입니다.

# %%
# 상태가치의 변화를 시각화
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm # color map

def init():
    # 배경색 초기화
    line.set_data([],[])
    return (line, )

def animate(i):
    # 프레임 단위로 그림을 그림
    # 각 칸에 상태가치 값으로 결정된 색을 칠함
    line, = ax.plot([0.5], [2.5], marker="s",
                   color=cm.jet(V[i][0]),markersize=85) # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                   color=cm.jet(V[i][1]),markersize=85) # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                   color=cm.jet(V[i][2]),markersize=85) # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                   color=cm.jet(V[i][3]),markersize=85) # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                   color=cm.jet(V[i][4]),markersize=85) # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                   color=cm.jet(V[i][5]),markersize=85) # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                   color=cm.jet(V[i][6]),markersize=85) # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                   color=cm.jet(V[i][7]),markersize=85) # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                   color=cm.jet(1.0),markersize=85) # S8    
    return (line, )

# 초기화 함수와 프레임 단위로 그림을 그리는 함수로 애니메이션을 생성
anim = animation.FuncAnimation(
        fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)

HTML(anim.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img73c890b04c494310a98c6afdc9d4b8c7">
#     <br>
#     <input id="_anim_slider73c890b04c494310a98c6afdc9d4b8c7" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim73c890b04c494310a98c6afdc9d4b8c7.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim73c890b04c494310a98c6afdc9d4b8c7.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select73c890b04c494310a98c6afdc9d4b8c7" class="anim_control">
#     <input type="radio" name="state"
#            value="once" checked> Once </input>
#     <input type="radio" name="state"
#            value="loop" > Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img73c890b04c494310a98c6afdc9d4b8c7";
#     var slider_id = "_anim_slider73c890b04c494310a98c6afdc9d4b8c7";
#     var loop_select_id = "_anim_loop_select73c890b04c494310a98c6afdc9d4b8c7";
#     var frames = new Array(101);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQA